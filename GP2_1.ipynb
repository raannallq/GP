# %% [markdown]
# <a href="https://colab.research.google.com/github/raannallq/GP/blob/main/GP2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title
# !pip install google_play_scraper

# %%
from google_play_scraper import reviews, Sort
import pandas as pd
import matplotlib.pyplot as plt

# %%
apps = {
    "Amazon": "com.amazon.mShop.android.shopping",
    "Shein": "com.zzkko",
    "AliExpress": "com.alibaba.aliexpresshd",
    "Noon": "com.noon.buyerapp",
    "Trendyol": "trendyol.com"
}

# %%
def label_sentiment(rating):
    if rating <= 2:
        return "Negative"
    elif rating == 3:
        return "Neutral"
    else:
        return "Positive"

# %%
all_reviews = []

for app_name, app_id in apps.items():
    print(f"Fetching reviews for {app_name}...")

    result, _ = reviews(
        app_id,
        lang="en",
        country="us",
        sort=Sort.NEWEST,
        count=3000
    )

    for r in result:
        all_reviews.append({
            "app_name": app_name,
            "review_text": r["content"],
            "rating": r["score"],
            "sentiment_label": label_sentiment(r["score"])
        })
# Out:
# Fetching reviews for Amazon...
# Fetching reviews for Shein...
# Fetching reviews for AliExpress...
# Fetching reviews for Noon...
# Fetching reviews for Trendyol...

# %%
df = pd.DataFrame(all_reviews)
df.head()
# Out:
#   app_name                                        review_text  rating  \
# 0   Amazon  won't let me change my password and take off m...       1
# 1   Amazon  It doesn't load and glitches. I can't find any...       1
# 2   Amazon  This used to be the best! Now, almost every sh...       2
# 3   Amazon  THIS IS UNFAIR! I've literally ordered multipl...       1
# 4   Amazon  way too hard to contact an agent for help. hor...       1
#
#   sentiment_label
# 0        Negative
# 1        Negative
# 2        Negative
# 3        Negative
# 4        Negative

# %%
df.to_csv("google_play_appS_reviews.csv", index=False)

# %%
from google.colab import files
files.download("google_play_appS_reviews.csv")
